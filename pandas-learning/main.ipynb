# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('customers.csv')
print(df)

# %%
df.head()
df.tail()
df.info()
df.describe()

# %%
df.columns
#df.index
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email'],
#       dtype='str')

# %%
df['Country']
len(df['Country'])
df['Country'].value_counts()
df['Country'].value_counts().plot(kind='pie')
plt.show()

# %%
df[['Country', 'City']]
# Out:
#             Country         City
# 0         Australia       Sydney
# 1    United Kingdom   Birmingham
# 2             Japan        Tokyo
# 3     United States      Phoenix
# 4         Australia     Brisbane
# ..              ...          ...
# 995           China     Shenzhen
# 996         Nigeria        Lagos
# 997   United States  Los Angeles
# 998       Singapore    Singapore
# 999  United Kingdom   Birmingham
#
# [1000 rows x 2 columns]

# %%
df.iloc[1]
df.iloc[10]['City']
# Out:
# 'Rio de Janeiro'

# %%
df[(df['Country'] == 'Germany') & (df['City'] == 'Berlin')]
len(df[(df['Country'] == 'Germany') & (df['City'] == 'Berlin')])
# Out:
# 21

# %%
df[(df['Country'] == 'Germany') | (df['City'] == 'Berlin')]
len(df[(df['Country'] == 'Germany') | (df['City'] == 'Berlin')])
# Out:
# 70

# %%
df[df['Country'].str.startswith('G')]

# %%
df[df['Country'].isin(['Germany', 'France'])]
df[~df['Country'].isin(['Germany', 'France'])]

# %%
df.loc[df["First Name"] == "Camille"]

# %%
df = df.drop(39)

# %%
df.rename(columns={'First Name': 'First_Name'}, inplace=True)
print(df.columns)
# Out:
# Index(['Index', 'Customer Id', 'First_Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email'],
#       dtype='str')

# %%
df["Company"].value_counts()

# %%
df.groupby('Country')['Company'].value_counts()
# Out:
# Country        Company
# Australia      Hammerspace          7
#                CloudPeak            4
#                Globex               3
#                Veridian Dynamics    3
#                Soylent Corp         3
#                                    ..
# United States  Cyberdyne Systems    2
#                DataSphere           2
#                Stay Puft Corp       2
#                Sabre Inc            1
#                CloudPeak            1
# Name: count, Length: 480, dtype: int64

# %%
df.to_csv('customers_updated.csv', index=False)
